# %%
# !python3 inference.py --model_dir="./exp/experiment14"
# Out:
# Loading Data..
# Calculating inference results..
# 100%|█████████████████████████████████████████| 314/314 [00:07<00:00, 41.35it/s]
# Inference Done!

# %%
# !python3 train.py
# Out:
# Namespace(attr='genre', batch_size=128, config=False, criterion='mse_loss', data_dir='/opt/ml/input/data/train/', dataset='AutoRecDataset', drop_ratio=0.1, early_stopping=5, embedding_dim=512, epochs=100, hidden_activation='identity', lr=0.0001, lr_decay_step=30, model='AutoRec', name='experiment', negative_num=100, optimizer='Adam', out_activation='sigmoid', scheduler='StepLR', seed=42, val_ratio=0.2)
# Loading Data..
# EPOCH 0
# ...
# 100%|█| 196/196 [00:03<00:00, 54.15it/s, Epoch=[0/100](100/196), MSE Loss=0.0889
# Calculating validation results...
# New best model for val loss : 9.43564824707692e-05! saving the best model..
# [Val] loss : 9.43564824707692e-05 || best loss: 9.43564824707692e-05
# EPOCH 1
# ...
# 100%|█| 196/196 [00:03<00:00, 61.07it/s, Epoch=[1/100](100/196), MSE Loss=0.0111
# Calculating validation results...
# New best model for val loss : 7.571725877731259e-05! saving the best model..
# [Val] loss : 7.571725877731259e-05 || best loss: 7.571725877731259e-05
# EPOCH 2
# ...
